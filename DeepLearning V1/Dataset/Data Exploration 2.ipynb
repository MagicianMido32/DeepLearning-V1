# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
matplotlib.rc('figure', figsize=(25, 15))

# %% [markdown]
# # =========================================================

# %% [markdown]
# # 1. All the data that was collected since Dr.Ahmed bought the plug
#   ##### Including his house, Hashim's house and Mo's House
#      From: 2020-10-12
#      To: 2021-02-18
#      Days: 129
#      Count: 35373
#      Size: 887KB

# %%
dfDataSinceTheBeginning = pd.read_csv("Data since the begining.csv")

# %%
dfDataSinceTheBeginning.describe()
# Out:
#               power
# count  35373.000000
# mean      69.390082
# std      130.005120
# min        0.000000
# 25%        0.000000
# 50%       81.680000
# 75%      122.160000
# max     2022.400000

# %%
dfDataSinceTheBeginning.head()
# Out:
#              occurtime   power
# 0  2020-10-12_18:30:00  126.32
# 1  2020-10-12_18:35:00  123.12
# 2  2020-10-12_18:40:00  122.72
# 3  2020-10-12_18:45:00  121.68
# 4  2020-10-12_18:50:00  123.28

# %%
dfDataSinceTheBeginning.tail()
# Out:
#                  occurtime  power
# 35368  2021-02-18_11:30:00  13.68
# 35369  2021-02-18_11:40:00   0.28
# 35370  2021-02-18_11:45:00   0.27
# 35371  2021-02-18_11:50:00   0.00
# 35372  2021-02-18_11:55:00   0.00

# %%
dfDataSinceTheBeginning.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %% [markdown]
# # =============================================================

# %% [markdown]
# # 2. Mo's total consumption
# ##### Including the consumption of (Fridge, Deep Freezer, Washer, Water pump)
#     From: 2020-12-09
#     To: 2021-02-18
#     Days: 71
#     Count: 19873
#     Size: 508KB

# %%
dfMosTotalConsumption = pd.read_csv('MyTotal Consumption.csv')

# %%
dfMosTotalConsumption.head()
# Out:
#              occurtime   power
# 0  2020-12-09_07:55:00  130.24
# 1  2020-12-09_08:00:00  127.76
# 2  2020-12-09_08:05:00  124.96
# 3  2020-12-09_08:10:00  122.24
# 4  2020-12-09_08:15:00    0.00

# %%
dfMosTotalConsumption.tail()
# Out:
#                  occurtime  power
# 19868  2021-02-18_11:30:00  13.68
# 19869  2021-02-18_11:40:00   0.28
# 19870  2021-02-18_11:45:00   0.27
# 19871  2021-02-18_11:50:00   0.00
# 19872  2021-02-18_11:55:00   0.00

# %%
dfMosTotalConsumption.describe()
# Out:
#               power
# count  19873.000000
# mean      69.283088
# std      164.797368
# min        0.000000
# 25%        0.000000
# 50%        3.440000
# 75%       94.720000
# max     2022.400000

# %%
dfMosTotalConsumption.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %% [markdown]
# # =========================================================

# %% [markdown]
# # 3. Fridge
#     From: 2020-12-10
#     To: 2020-12-26
#     Days: 16
#     Count: 4777
#     Size: 124KB

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("FridgeAbnormal.png")
plt.imshow(image)
plt.show()

# %%
dfFridge = pd.read_csv('MyFridge.csv')

# %%
dfFridge.describe()
# Out:
#              power
# count  4777.000000
# mean     74.092998
# std      64.143171
# min       0.000000
# 25%       0.000000
# 50%     120.000000
# 75%     125.520000
# max     387.600000

# %%
dfFridge.head()
# Out:
#              occurtime   power
# 0  2020-12-10_00:05:00  130.16
# 1  2020-12-10_00:10:00  124.64
# 2  2020-12-10_00:15:00  121.36
# 3  2020-12-10_00:20:00  120.16
# 4  2020-12-10_00:25:00    0.00

# %%
dfFridge.tail()
# Out:
#                 occurtime   power
# 4772  2020-12-26_23:35:00    0.00
# 4773  2020-12-26_23:40:00    0.00
# 4774  2020-12-26_23:45:00    0.00
# 4775  2020-12-26_23:50:00  129.60
# 4776  2020-12-26_23:55:00  121.04

# %%
dfFridge.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %% [markdown]
# # ============================================================

# %% [markdown]
# # 4. Deep Freezer
#     From: 2020-12-28
#     To: 2021-01-14
#     Days: 17
#     Count: 4612
#     Size: 119KB

# %%
dfDFreezer = pd.read_csv('My Deep Freezer.csv')

# %%
dfDFreezer.describe()
# Out:
#              power
# count  4612.000000
# mean     79.395817
# std      30.788192
# min       0.000000
# 25%      88.480000
# 50%      90.320000
# 75%      91.920000
# max     110.720000

# %%
dfDFreezer.head()
# Out:
#              occurtime  power
# 0  2020-12-28_00:05:00   0.00
# 1  2020-12-28_00:10:00  99.20
# 2  2020-12-28_00:15:00  95.68
# 3  2020-12-28_00:20:00  93.20
# 4  2020-12-28_00:25:00  91.92

# %%
dfDFreezer.tail()
# Out:
#                 occurtime  power
# 4607  2021-01-13_23:40:00  90.40
# 4608  2021-01-13_23:45:00  91.36
# 4609  2021-01-13_23:50:00  90.72
# 4610  2021-01-13_23:55:00  91.28
# 4611  2021-01-14_00:00:00  90.80

# %%
dfDFreezer.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %% [markdown]
# # ====================================================

# %% [markdown]
# # 5.Washer
#     From: 2021-01-15
#     To: 2021-01-26
#     Days: 11
#     Count: 3107
#     Size: 79KB

# %%
dfWasher = pd.read_csv('My Washer.csv')

# %%
dfWasher.describe()
# Out:
#              power
# count  3107.000000
# mean     52.040496
# std     272.870991
# min       0.000000
# 25%       3.440000
# 50%       3.440000
# 75%       3.440000
# max    2022.400000

# %%
dfWasher.head()
# Out:
#              occurtime    power
# 0  2021-01-15_00:50:00     0.46
# 1  2021-01-15_00:55:00     0.50
# 2  2021-01-15_01:00:00  1765.60
# 3  2021-01-15_01:05:00  1691.68
# 4  2021-01-15_01:10:00  1712.72

# %%
dfWasher.tail()
# Out:
#                 occurtime   power
# 3102  2021-01-25_23:40:00    5.92
# 3103  2021-01-25_23:45:00  106.00
# 3104  2021-01-25_23:50:00    3.44
# 3105  2021-01-25_23:55:00    3.44
# 3106  2021-01-26_00:00:00    3.44

# %%
dfWasher.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %% [markdown]
# # ===========================================================

# %% [markdown]
# # 6. Water pump
#     From: 2021-01-27
#     To: 2021-02-11
#     Days: 15
#     Count: 4257
#     Size: 105KB

# %%
dfPump = pd.read_csv('MyWaterPump.csv')

# %%
dfPump.describe()
# Out:
#              power
# count  4257.000000
# mean     68.448898
# std     239.966491
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max    1397.600000

# %%
dfPump.head()
# Out:
#              occurtime  power
# 0  2021-01-27_00:05:00    0.0
# 1  2021-01-27_00:10:00    0.0
# 2  2021-01-27_00:15:00    0.0
# 3  2021-01-27_00:20:00    0.0
# 4  2021-01-27_00:25:00    0.0

# %%
dfPump.tail()
# Out:
#                 occurtime  power
# 4252  2021-02-10_23:40:00    0.0
# 4253  2021-02-10_23:45:00    0.0
# 4254  2021-02-10_23:50:00    0.0
# 4255  2021-02-10_23:55:00    0.0
# 4256  2021-02-11_00:00:00    0.0

# %%
dfPump.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %% [markdown]
# # =============================================================
