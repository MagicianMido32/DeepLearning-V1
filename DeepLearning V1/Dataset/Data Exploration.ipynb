# %%
import pandas as pd

# %%
df = pd.read_csv("mine.csv")

# %%
df.head()
# Out:
#              occurtime   power
# 0  2020-12-09_07:55:00  130.24
# 1  2020-12-09_08:00:00  127.76
# 2  2020-12-09_08:05:00  124.96
# 3  2020-12-09_08:10:00  122.24
# 4  2020-12-09_08:15:00    0.00

# %%
df['occurtime'] = pd.to_datetime(df['occurtime'],format="%Y-%m-%d_%H:%M:%S")

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
matplotlib.rc('figure', figsize=(50, 25))

# %%
df.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %%
from datetime import datetime, timedelta
df2 = df[df["occurtime"] > datetime(2021,2,12)]

# %%
df2.head()
# Out:
#                 occurtime   power
# 18020 2021-02-12 00:05:00    0.00
# 18021 2021-02-12 00:10:00    0.00
# 18022 2021-02-12 00:15:00    0.00
# 18023 2021-02-12 00:20:00  125.36
# 18024 2021-02-12 00:25:00  123.28

# %%
df2.plot(x='occurtime',y='power',kind='line',x_compat=True)
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %%
MyDF = df2[df2['occurtime']<=datetime(2021,2,11)]

# %%
MyDF.head()
# Out:
#                 occurtime  power
# 13482 2021-01-27 00:05:00    0.0
# 13483 2021-01-27 00:10:00    0.0
# 13484 2021-01-27 00:15:00    0.0
# 13485 2021-01-27 00:20:00    0.0
# 13486 2021-01-27 00:25:00    0.0

# %%
MyDF.plot(x='occurtime',y='power',kind='line')
# Out:
# <AxesSubplot:xlabel='occurtime'>

# %%
MyDF.to_csv('MyWaterPump.csv',index=False,date_format="%Y-%m-%d_%H:%M:%S")
