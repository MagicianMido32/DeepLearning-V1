# %%
import pandas as pd

# %%
df = pd.read_csv('MyFridge.csv')

# %%
df.describe()
# Out:
#              power
# count  4491.000000
# mean     74.399795
# std      64.106754
# min       0.000000
# 25%       0.000000
# 50%     120.000000
# 75%     125.440000
# max     387.600000

# %%
vals = df['power'].diff().dropna().to_numpy().reshape(-1,1)

# %%
import math

# %%
split_by = math.ceil(0.7*len(vals))
lag = 60

# %%
train = vals[:split_by]

# %%
test = vals[split_by-lag:]

# %%
x_train =[]
y_train = []
for i in range(lag,len(train)):
  x_train.append(train[i - lag:i,0])
  y_train.append(train[i,0])

# %%
import numpy as np

# %%
y_train = np.asarray(y_train)
x_train = np.asarray(x_train)
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],1) # rows,lag,[]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['MAPE', 'accuracy'])

# %%
model.fit(x_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 97/97 [==============================] - 16s 102ms/step - loss: 4595.2974 - MAPE: 174573574.6888 - accuracy: 0.1410
# Epoch 2/100
# 97/97 [==============================] - 11s 109ms/step - loss: 4201.4274 - MAPE: 380264945.7551 - accuracy: 0.2261
# Epoch 3/100
# 97/97 [==============================] - 11s 109ms/step - loss: 3538.6131 - MAPE: 1950128244.2449 - accuracy: 0.1032
# Epoch 4/100
# 97/97 [==============================] - 11s 109ms/step - loss: 3359.8043 - MAPE: 2806867956.2449 - accuracy: 0.0830
# Epoch 5/100
# 97/97 [==============================] - 11s 113ms/step - loss: 3228.0472 - MAPE: 3296889910.8571 - accuracy: 0.0725
# Epoch 6/100
# 97/97 [==============================] - 11s 113ms/step - loss: 3158.8608 - MAPE: 3873208599.5102 - accuracy: 0.0821
# Epoch 7/100
# 97/97 [==============================] - 11s 113ms/step - loss: 2847.4842 - MAPE: 3914905511.1837 - accuracy: 0.0674
# Epoch 8/100
# 97/97 [==============================] - 11s 111ms/step - loss: 2798.4893 - MAPE: 4406102959.0204 - accuracy: 0.0702
# Epoch 9/100
# 97/97 [==============================] - 11s 112ms/step - loss: 2793.4665 - MAPE: 4576582426.1224 - accuracy: 0.0721
# Epoch 10/100
# 97/97 [==============================] - 11s 111ms/step - loss: 2500.7958 - MAPE: 4436521336.1633 - accuracy: 0.1012
# Epoch 11/100
# 97/97 [==============================] - 11s 111ms/step - loss: 2418.9072 - MAPE: 5239311480.1633 - accuracy: 0.0787
# Epoch 12/100
# 97/97 [==============================] - 11s 112ms/step - loss: 2412.5861 - MAPE: 5463238656.0000 - accuracy: 0.0864
# Epoch 13/100
# 97/97 [==============================] - 11s 111ms/step - loss: 2421.0659 - MAPE: 5349646908.0816 - accuracy: 0.0952
# Epoch 14/100
# 97/97 [==============================] - 11s 112ms/step - loss: 2407.5484 - MAPE: 6077295715.2653 - accuracy: 0.0958
# Epoch 15/100
# 97/97 [==============================] - 11s 112ms/step - loss: 2196.2242 - MAPE: 5322631228.0816 - accuracy: 0.1025
# Epoch 16/100
# 97/97 [==============================] - 11s 112ms/step - loss: 2189.6695 - MAPE: 5890987935.3469 - accuracy: 0.0983
# Epoch 17/100
# 97/97 [==============================] - 11s 112ms/step - loss: 2218.4388 - MAPE: 6665408809.7959 - accuracy: 0.0984
# Epoch 18/100
# 97/97 [==============================] - 11s 112ms/step - loss: 2081.0848 - MAPE: 5757419164.7347 - accuracy: 0.1016
# Epoch 19/100
# 97/97 [==============================] - 11s 113ms/step - loss: 2136.2013 - MAPE: 6087861822.6939 - accuracy: 0.0899
# Epoch 20/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1862.8965 - MAPE: 5931083128.1633 - accuracy: 0.1069
# Epoch 21/100
# 97/97 [==============================] - 11s 113ms/step - loss: 2110.7929 - MAPE: 6028857302.2041 - accuracy: 0.1019
# Epoch 22/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1810.2606 - MAPE: 5530880815.0204 - accuracy: 0.0931
# Epoch 23/100
# 97/97 [==============================] - 11s 111ms/step - loss: 1871.0221 - MAPE: 5287596708.5714 - accuracy: 0.0915
# Epoch 24/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1741.8033 - MAPE: 5501364997.2245 - accuracy: 0.1002
# Epoch 25/100
# 97/97 [==============================] - 11s 111ms/step - loss: 1701.9185 - MAPE: 5293941104.3265 - accuracy: 0.0818
# Epoch 26/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1685.9901 - MAPE: 5619666126.3673 - accuracy: 0.1006
# Epoch 27/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1712.8939 - MAPE: 5104995004.0816 - accuracy: 0.1026
# Epoch 28/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1749.2220 - MAPE: 5440503463.1837 - accuracy: 0.0984
# Epoch 29/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1537.4159 - MAPE: 5251211088.9796 - accuracy: 0.0914
# Epoch 30/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1600.3375 - MAPE: 4814431179.7551 - accuracy: 0.1035
# Epoch 31/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1522.0147 - MAPE: 5024524240.9796 - accuracy: 0.0991
# Epoch 32/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1556.8602 - MAPE: 4939246968.1633 - accuracy: 0.1125
# Epoch 33/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1512.4837 - MAPE: 5400313218.6122 - accuracy: 0.1146
# Epoch 34/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1567.0791 - MAPE: 5520200064.0000 - accuracy: 0.0912
# Epoch 35/100
# 97/97 [==============================] - 11s 114ms/step - loss: 1488.4819 - MAPE: 5297782230.2041 - accuracy: 0.1158
# Epoch 36/100
# 97/97 [==============================] - 11s 114ms/step - loss: 1368.4941 - MAPE: 4700366571.1020 - accuracy: 0.0987
# Epoch 37/100
# 97/97 [==============================] - 11s 115ms/step - loss: 1480.6898 - MAPE: 4945711939.9184 - accuracy: 0.1018
# Epoch 38/100
# 97/97 [==============================] - 11s 115ms/step - loss: 1451.5961 - MAPE: 5307621360.3265 - accuracy: 0.1058
# Epoch 39/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1529.3088 - MAPE: 4991165976.8163 - accuracy: 0.1026
# Epoch 40/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1389.0220 - MAPE: 4481333888.0000 - accuracy: 0.1010
# Epoch 41/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1297.0076 - MAPE: 5023085463.5102 - accuracy: 0.1018
# Epoch 42/100
# 97/97 [==============================] - 11s 114ms/step - loss: 1375.9022 - MAPE: 4792035659.7551 - accuracy: 0.0949
# Epoch 43/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1378.3987 - MAPE: 4826592329.1429 - accuracy: 0.1037
# Epoch 44/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1366.9209 - MAPE: 4292636847.0204 - accuracy: 0.1139
# Epoch 45/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1388.8599 - MAPE: 4500137095.8367 - accuracy: 0.1041
# Epoch 46/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1296.7851 - MAPE: 5097734810.1224 - accuracy: 0.1075
# Epoch 47/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1315.0113 - MAPE: 4793483028.8980 - accuracy: 0.1067
# Epoch 48/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1356.0916 - MAPE: 4911805612.4082 - accuracy: 0.1130
# Epoch 49/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1299.6490 - MAPE: 5040009479.8367 - accuracy: 0.1008
# Epoch 50/100
# 97/97 [==============================] - 11s 112ms/step - loss: 
100
# 97/97 [==============================] - 11s 112ms/step - loss: 1081.6465 - MAPE: 4662366534.5306 - accuracy: 0.1049
# Epoch 85/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1001.0550 - MAPE: 4423911016.4898 - accuracy: 0.1121
# Epoch 86/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1082.5212 - MAPE: 4287085131.7551 - accuracy: 0.1176
# Epoch 87/100
# 97/97 [==============================] - 11s 114ms/step - loss: 1034.1850 - MAPE: 4079483540.8980 - accuracy: 0.1136
# Epoch 88/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1011.0554 - MAPE: 4318692973.7143 - accuracy: 0.1176
# Epoch 89/100
# 97/97 [==============================] - 11s 113ms/step - loss: 976.6831 - MAPE: 4161154123.7551 - accuracy: 0.1071
# Epoch 90/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1024.9971 - MAPE: 3996368023.5102 - accuracy: 0.1218
# Epoch 91/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1033.8139 - MAPE: 4234636089.4694 - accuracy: 0.1283
# Epoch 92/100
# 97/97 [==============================] - 11s 113ms/step - loss: 1048.7543 - MAPE: 3994511565.0612 - accuracy: 0.1086
# Epoch 93/100
# 97/97 [==============================] - 11s 114ms/step - loss: 977.3438 - MAPE: 3884362775.5102 - accuracy: 0.1259
# Epoch 94/100
# 97/97 [==============================] - 11s 115ms/step - loss: 1097.4882 - MAPE: 4334974834.9388 - accuracy: 0.1302
# Epoch 95/100
# 97/97 [==============================] - 11s 114ms/step - loss: 1065.4860 - MAPE: 4343705121.9592 - accuracy: 0.1244
# Epoch 96/100
# 97/97 [==============================] - 11s 114ms/step - loss: 1118.7714 - MAPE: 4400377059.2653 - accuracy: 0.1140
# Epoch 97/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1022.9610 - MAPE: 4322123141.2245 - accuracy: 0.1133
# Epoch 98/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1076.1383 - MAPE: 4171390966.8571 - accuracy: 0.1157
# Epoch 99/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1180.0621 - MAPE: 4242192002.6122 - accuracy: 0.1141
# Epoch 100/100
# 97/97 [==============================] - 11s 112ms/step - loss: 1002.8479 - MAPE: 4108985500.7347 - accuracy: 0.1294

# %%
x_test = []
for i in range(lag,len(test)):
  x_test.append(test[i-lag:i,0])

# %%
x_test = np.asarray(x_test)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],1) # rows,lag,[]

# %%
predictions = model.predict(x_test)

# %%
predictions = predictions.flatten()

# %%
predictions = predictions + df['power'][split_by:-1]

# %%
test = df['power'][split_by+1:]

# %%
dates = df['occurtime'][split_by+1:]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(100, 50))
plt.xticks(np.arange(0, len(test), lag))
plt.plot(dates, test, color='blue', label='Real')
plt.plot(dates, predictions, color='red', label='predicted')
plt.title('real vs predicted')
plt.xlabel('occurtime')
plt.ylabel('power')
plt.legend(["Real values", "Predicted values"], loc="upper left")
plt.show()

# %%
def get_mape(y_true, y_predicted):
    y_true, y_predicted = np.array(y_true), np.array(y_predicted)
    mape = np.mean(np.abs((y_true - y_predicted) / y_true)) * 100
    return mape
 
 
def get_rmse(y_true, y_predicted):
    rmse = np.sqrt(np.mean(np.power((y_true - y_predicted), 2)))
    return rmse
  
def get_sum_error(y_true, y_predicted):
  return sum(y_true)-sum(y_predicted)

# %%
print(get_rmse(test, predictions)) # 0 ->
# Out:
# 59.58449527856328

# %%
print(get_sum_error(test, predictions))
# Out:
# 3332.0014418792853
